# %% [markdown]
# <a href="https://colab.research.google.com/github/PEIDI-CHEN/123/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 从txt文件读取数据并进行清洗
def read_and_clean_data_from_txt(file_path, keywords):
    input_sequences = []
    labels = []
    temp_sequences = []
    temp_labels = []
    keywords_lower = [word.lower() for word in keywords]  # 将关键词转换为小写
    with open(file_path, 'r') as file:
        for line in file:
            data = line.strip().split()
            if len(data) < 2:
                continue  # 忽略不完整的数据行
            # 检查消息中是否包含关键词
            if any(word.lower() in keywords_lower for word in data[:-1]):
                # 将消息中的关键词转换为小写，并检查顺序是否与keywords相同
                if tuple(word.lower() for word in data[:-1]) == tuple(keywords_lower):
                    labels.append(0)  # 与keywords相同的顺序，设置为0
                else:
                    labels.append(1)  # 与keywords不同的顺序，设置为1
                temp_sequences.append(data[:-1])  # 保留消息中的关键词序列
            if len(temp_sequences) == 12:  # 每12个信息聚合一次
                if any(seq in temp_sequences for seq in input_sequences):
                    temp_sequences = []
                    temp_labels = []
                else:
                    input_sequences.append(temp_sequences)
                    labels.append(temp_labels)
                    temp_sequences = []
                    temp_labels = []
    return input_sequences, labels

# 示例数据
file_path = '/content/sample_data/diag_log_20210716_142408_f634e5a31bf277bd6ad32a90ccc407e5_Xiaomi-Mi10_46000.txt'  # 修改为你的文件路径
output_file = '/content/sample_data/cleaned_data.txt'  # 输出文件路径
keywords = ["RRCConnectionReconfiguration", "RRCConnectionReconfigurationComplete",
            "ULInformationTransfer", "RRCConnectionRequest", "RRCConnectionSetup", "RRCConnectionSetupComplete",
            "DLInformation Transfer", "ULInformation Transfer", "SecurityModeCommand",
            "SecurityModeComplete", "UECapabilityEnquiry", "UECapabilityInformation"]
input_sequences, labels = read_and_clean_data_from_txt(file_path, keywords)


# 将处理后的信息保存为txt文件
with open(output_file, 'w') as file:
    for sequences, seq_labels in zip(input_sequences, labels):
        for seq, label in zip(sequences, seq_labels):
            line = ' '.join(seq) + ' ' + str(label) + '\n'
            file.write(line)

# 恢复聚合前的顺序
restored_sequences = []
restored_labels = []
for sequences, seq_labels in zip(input_sequences, labels):
    for seq, label in zip(sequences, seq_labels):
        restored_sequences.append(seq)
        restored_labels.append(label)

# 将处理后的信息保存为txt文件
with open(output_file, 'w') as file:
    for seq, label in zip(restored_sequences, restored_labels):
        line = ' '.join(seq) + ' ' + str(label) + '\n'
        file.write(line)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5088d6476eb5> in <cell line: 43>()
#      43 with open(output_file, 'w') as file:
#      44     for sequences, seq_labels in zip(input_sequences, labels):
# ---> 45         for seq, label in zip(sequences, seq_labels):
#      46             line = ' '.join(seq) + ' ' + str(label) + '\n'
#      47             file.write(line)
#
# TypeError: 'int' object is not iterable

# %%
# 从txt文件读取数据并进行清洗
def read_and_clean_data_from_txt(file_path, keywords):
    input_sequences = []
    labels = []
    temp_sequences = []
    temp_labels = []
    keywords_lower = [word.lower() for word in keywords]  # 将关键词转换为小写
    with open(file_path, 'r') as file:
        for line in file:
            data = line.strip().split()
            if len(data) < 2:
                continue  # 忽略不完整的数据行
            # 检查消息中是否包含关键词
            if any(word.lower() in keywords_lower for word in data[:-1]):
                # 将消息中的关键词转换为小写，并检查顺序是否与keywords相同
                if tuple(word.lower() for word in data[:-1]) == tuple(keywords_lower):
                    labels.append(0)  # 与keywords相同的顺序，设置为0
                else:
                    labels.append(1)  # 与keywords不同的顺序，设置为1
                temp_sequences.append(data[:-1])  # 保留消息中的关键词序列
            if len(temp_sequences) == 12:  # 每12个信息聚合一次
                if any(seq in temp_sequences for seq in input_sequences):
                    temp_sequences = []
                    temp_labels = []
                else:
                    input_sequences.append(temp_sequences)
                    labels.append(temp_labels)
                    temp_sequences = []
                    temp_labels = []
    return input_sequences, labels

# 示例数据
file_path = '/content/sample_data/diag_log_20210716_142408_f634e5a31bf277bd6ad32a90ccc407e5_Xiaomi-Mi10_46000.txt'  # 修改为你的文件路径
output_file = '/content/sample_data/cleaned_data.txt'  # 输出文件路径
keywords = ["RRCConnectionReconfiguration", "RRCConnectionReconfigurationComplete",
            "ULInformationTransfer", "RRCConnectionRequest", "RRCConnectionSetup", "RRCConnectionSetupComplete",
            "DLInformation Transfer", "ULInformation Transfer", "SecurityModeCommand",
            "SecurityModeComplete", "UECapabilityEnquiry", "UECapabilityInformation"]
input_sequences, labels = read_and_clean_data_from_txt(file_path, keywords)

# 恢复聚合前的顺序
restored_sequences = []
restored_labels = []
for sequences, seq_labels in zip(input_sequences, labels):
    for seq, label in zip(sequences, seq_labels):
        restored_sequences.append(seq)
        restored_labels.append(label)

# 将处理后的信息保存为txt文件
with open(output_file, 'w') as file:
    for seq, label in zip(restored_sequences, restored_labels):
        line = ' '.join(seq) + ' ' + str(label) + '\n'
        file.write(line)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-54f8b7cf706f> in <cell line: 44>()
#      43 restored_labels = []
#      44 for sequences, seq_labels in zip(input_sequences, labels):
# ---> 45     for seq, label in zip(sequences, seq_labels):
#      46         restored_sequences.append(seq)
#      47         restored_labels.append(label)
#
# TypeError: 'int' object is not iterable

# %%
def read_and_clean_data_from_txt(file_path, keywords):
    input_sequences = []
    labels = []
    keywords_lower = [word.lower() for word in keywords]  # 将关键词转换为小写
    current_set = set()  # 存储当前已经到达的信息
    with open(file_path, 'r') as file:
        for line in file:
            data = line.strip().split()
            if len(data) < 2:
                continue  # 忽略不完整的数据行
            # 检查消息中是否包含关键词
            if any(word.lower() in keywords_lower for word in data[:-1]):
                # 将消息中的关键词转换为小写，并加入当前集合
                current_set.update(word.lower() for word in data[:-1])
                # 检查当前集合是否包含所有关键词
                if set(keywords_lower).issubset(current_set):
                    input_sequences.append(data[:-1])  # 将数据添加到输入序列中
                    labels.append(0)  # 标记为0，表示信息已全部到达
                    current_set = set()  # 清空当前集合
    return input_sequences, labels

# 示例数据
file_path = '/content/sample_data/diag_log_20210716_142408_f634e5a31bf277bd6ad32a90ccc407e5_Xiaomi-Mi10_46000.txt'  # 修改为你的文件路径
output_file = '/content/sample_data/cleaned_data.txt'  # 输出文件路径
keywords = ["RRCConnectionReconfiguration", "RRCConnectionReconfigurationComplete",
            "ULInformationTransfer", "RRCConnectionRequest", "RRCConnectionSetup", "RRCConnectionSetupComplete",
            "DLInformation Transfer", "ULInformation Transfer", "SecurityModeCommand",
            "SecurityModeComplete", "UECapabilityEnquiry", "UECapabilityInformation"]
input_sequences, labels = read_and_clean_data_from_txt(file_path, keywords)

# 将处理后的信息保存为txt文件
with open(output_file, 'w') as file:
    for seq, label in zip(input_sequences, labels):
        line = ' '.join(seq) + ' ' + str(label) + '\n'
        file.write(line)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-424e87950963> in <cell line: 29>()
#      27             "DLInformation Transfer", "ULInformation Transfer", "SecurityModeCommand",
#      28             "SecurityModeComplete", "UECapabilityEnquiry", "UECapabilityInformation"]
# ---> 29 input_sequences, labels = read_and_clean_data_from_txt(file_path, keywords)
#      30
#      31 # 将处理后的信息保存为txt文件
#
# <ipython-input-9-424e87950963> in read_and_clean_data_from_txt(file_path, keywords)
#      10                 continue  # 忽略不完整的数据行
#      11             # 检查消息中是否包含关键词
# ---> 12             if any(word.lower() in keywords_lower for word in data[:-1].lower()):
#      13                 # 将消息中的关键词转换为小写，并加入当前集合
#      14                 current_set.update(word.lower() for word in data[:-1])
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
def read_and_clean_data_from_txt(file_path, keywords):
    input_sequences = []
    labels = []
    keywords_lower = [word.lower() for word in keywords]  # 将关键词转换为小写
    current_set = set()  # 存储当前已经到达的信息
    with open(file_path, 'r') as file:
        for line in file:
            data = line.strip().split()
            if len(data) < 2:
                continue  # 忽略不完整的数据行
            # 将数据转换为小写
            data_lower = [word.lower() for word in data]
            # 检查消息中是否包含关键词
            if any(word.lower() in keywords_lower for word in data_lower[:-1]):
                # 将消息中的关键词转换为小写，并加入当前集合
                current_set.update(word.lower() for word in data_lower[:-1])
                # 检查当前集合是否包含所有关键词且每个关键词都只出现一次
                if set(keywords_lower).issubset(current_set) and len(current_set) == len(data_lower[:-1]):
                    input_sequences.append(data[:-1])  # 将数据添加到输入序列中
                    labels.append(0)  # 标记为0，表示信息已全部到达
                    current_set = set()  # 清空当前集合
    return input_sequences, labels

# 示例数据
file_path = '/content/sample_data/diag_log_20210716_142408_f634e5a31bf277bd6ad32a90ccc407e5_Xiaomi-Mi10_46000.txt'  # 修改为你的文件路径
output_file = '/content/sample_data/cleaned_data.txt'  # 输出文件路径
keywords = ["RRCConnectionReconfiguration", "RRCConnectionReconfigurationComplete",
            "ULInformationTransfer", "RRCConnectionRequest", "RRCConnectionSetup", "RRCConnectionSetupComplete",
            "DLInformation Transfer", "ULInformation Transfer", "SecurityModeCommand",
            "SecurityModeComplete", "UECapabilityEnquiry", "UECapabilityInformation"]
input_sequences, labels = read_and_clean_data_from_txt(file_path, keywords)

# 将处理后的信息保存为txt文件
with open(output_file, 'w') as file:
    for seq, label in zip(input_sequences, labels):
        line = ' '.join(seq) + ' ' + str(label) + '\n'
        file.write(line)

# %%
from os import write
def mark_sequence(file_path, keywords):
    marked_sequences = []  # 存储标记后的信息序列
    keywords_lower = [word.lower() for word in keywords]
    current_keywords = []  # 存储当前已经出现的关键词序列
    next_keywords = []  # 存储下一个关键词序列
    third_keywords = []  # 存储第三个关键词序列
    forth_keywords = []  # 存储第四个关键词序列
    fifth_keywords = []  # 存储第五个关键词序列
    sixth_keywords = []  # 存储第六个关键词序列
    seventh_keywords = []  # 存储第七个关键词序列
    eighth_keywords = []  # 存储第八个关键词序列
    id_keywords1 = []
    id_keywords2 = []
    id_keywords3 = []
    id_keywords4 = []
    id_keywords5 = []
    id_keywords6 = []
    id_keywords7 = []
    id_keywords8 = []
    #ninth_keywords = []  # 存储第九个关键词序列
    #tenth_keywords = []  # 存储第十个关键词序列
    with open(file_path, 'r') as file:
        for line in file:
            words = line.strip().split()  # 按空格分割每行信息
            data_lower = [word.lower() for word in words]  # 将单词转换为小写
            for word in data_lower:
                if len(keywords_lower) == len(current_keywords):
                  tem = 0
                  while tem < len(current_keywords):
                    if keywords_lower[tem] in current_keywords[tem]:
                      marked_sequences.append((current_keywords[tem], 0))  # 关键词顺序相同，标记为0
                    else:
                      marked_sequences.append((current_keywords[tem], 1))  # 关键词顺序不同，标记为1
                    tem += 1
                  current_keywords = []  # 清空当前关键词序列
                if len(keywords_lower) == len(next_keywords):
                  tem = 0
                  while tem < len(next_keywords):
                    if keywords_lower[tem] in next_keywords[tem]:
                      marked_sequences.append((next_keywords[tem], 0))  # 关键词顺序相同，标记为0
                    else:
                      marked_sequences.append((next_keywords[tem], 1))  # 关键词顺序不同，标记为1
                    tem += 1
                  next_keywords = []  # 清空下一个关键词序列
                if len(keywords_lower) == len(third_keywords):
                  tem = 0
                  while tem < len(third_keywords):
                    if keywords_lower[tem] in third_keywords[tem]:
                      marked_sequences.append((third_keywords[tem], 0))
                    else:
                      marked_sequences.append((third_keywords[tem], 1))
                    tem += 1
                  third_keywords = []  # 清空第三个关键词序列
                if len(keywords_lower) == len(forth_keywords):
                  tem = 0
                  while tem < len(forth_keywords):
                    if keywords_lower[tem] in forth_keywords[tem]:
                      marked_sequences.append((forth_keywords[tem], 0))
                    else:
                      marked_sequences.append((forth_keywords[tem], 1))
                    tem += 1
                  forth_keywords = []  # 清空第四个关键词序列
                if len(keywords_lower) == len(fifth_keywords):
                  tem = 0
                  while tem < len(fifth_keywords):
                    if keywords_lower[tem] in fifth_keywords[tem]:
                      marked_sequences.append((fifth_keywords[tem], 0))
                    else:
                      marked_sequences.append((fifth_keywords[tem], 1))
                    tem += 1
                  fifth_keywords = []  # 清空第五个关键词序列
                if len(keywords_lower) == len(sixth_keywords):
                  tem = 0
                  while tem < len(sixth_keywords):
                    if keywords_lower[tem] in sixth_keywords[tem]:
                      marked_sequences.append((sixth_keywords[tem], 0))
                    else:
                      marked_sequences.append((sixth_keywords[tem], 1))
                    tem += 1
                  sixth_keywords = []  # 清空第六个关键词序列
                if len(keywords_lower) == len(seventh_keywords):
                  tem = 0
                  while tem < len(seventh_keywords):
                    if keywords_lower[tem] in seventh_keywords[tem]:
                      marked_sequences.append((seventh_keywords[tem], 0))
                    else:
                      marked_sequences.append((seventh_keywords[tem], 1))
                    tem += 1
                  seventh_keywords = []  # 清空第七个关键词序列
                if len(keywords_lower) == len(eighth_keywords):
                  tem = 0
                  while tem < len(eighth_keywords):
                    if keywords_lower[tem] in eighth_keywords[tem]:
                      marked_sequences.append((eighth_keywords[tem], 0))
                    else:
                      marked_sequences.append((eighth_keywords[tem], 1))
                    tem += 1
                  eighth_keywords = []  # 清空第八个关键词序列

                if word in keywords_lower and word not in id_keywords1:
                    current_keywords.append(data_lower)
                    id_keywords1.append(word)
                if word in keywords_lower and word in id_keywords1 and word not in id_keywords2:
                    next_keywords.append(data_lower)
                    id_keywords2.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word not in id_keywords3:
                    third_keywords.append(data_lower)
                    id_keywords3.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word not in id_keywords4:
                    forth_keywords.append(data_lower)
                    id_keywords4.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word in id_keywords4 and word not in id_keywords5:
                    fifth_keywords.append(data_lower)
                    id_keywords5.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word in id_keywords4 and word in id_keywords5 and word not in id_keywords6:
                    sixth_keywords.append(data_lower)
                    id_keywords6.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word in id_keywords4 and word in id_keywords5 and word in id_keywords6 and word not in id_keywords7:
                    seventh_keywords.append(data_lower)
                    id_keywords7.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word in id_keywords4 and word in id_keywords5 and word in id_keywords6 and word in id_keywords7 and word not in id_keywords8:
                    eighth_keywords.append(data_lower)
                    id_keywords8.append(word)
    return marked_sequences

# 示例数据
file_path = '/content/sample_data/diag_log_20210716_150057_f634e5a31bf277bd6ad32a90ccc407e5_Xiaomi-Mi10_46000.txt'
keywords = ["RRCConnectionReconfiguration", "RRCConnectionReconfigurationComplete",
            "ULInformationTransfer", "RRCConnectionRequest", "RRCConnectionSetup", "RRCConnectionSetupComplete",
            "SecurityModeCommand",
            "SecurityModeComplete", "UECapabilityEnquiry", "UECapabilityInformation"]
output_file = '/content/sample_data/marked_data1.txt'

marked_sequences = mark_sequence(file_path, keywords)

# 将标记后的信息写入到输出文件
with open(output_file, 'w') as file:
    for seq, label in marked_sequences:
        line = ' '.join(seq) + ' ' + str(label) + '\n'
        file.write(line)

# %%
from os import write
def mark_sequence(file_path, keywords):
    marked_sequences = []  # 存储标记后的信息序列
    keywords_lower = [word.lower() for word in keywords]
    current_keywords = []  # 存储当前已经出现的关键词序列
    next_keywords = []  # 存储下一个关键词序列
    third_keywords = []  # 存储第三个关键词序列
    forth_keywords = []  # 存储第四个关键词序列
    fifth_keywords = []  # 存储第五个关键词序列
    sixth_keywords = []  # 存储第六个关键词序列
    seventh_keywords = []  # 存储第七个关键词序列
    eighth_keywords = []  # 存储第八个关键词序列
    id_keywords1 = []
    id_keywords2 = []
    id_keywords3 = []
    id_keywords4 = []
    id_keywords5 = []
    id_keywords6 = []
    id_keywords7 = []
    id_keywords8 = []
    #ninth_keywords = []  # 存储第九个关键词序列
    #tenth_keywords = []  # 存储第十个关键词序列
    with open(file_path, 'r') as file:
        for line in file:
            words = line.strip().split()  # 按空格分割每行信息
            data_lower = [word.lower() for word in words]  # 将单词转换为小写
            for word in data_lower:
                if len(keywords_lower) == len(current_keywords):
                  tem = 0
                  while tem < len(current_keywords):
                    if keywords_lower[tem] in current_keywords[tem]:
                      marked_sequences.append((current_keywords[tem], 0))  # 关键词顺序相同，标记为0
                    else:
                      marked_sequences.append((current_keywords[tem], 1))  # 关键词顺序不同，标记为1
                    tem += 1
                  current_keywords = []  # 清空当前关键词序列
                if len(keywords_lower) == len(next_keywords):
                  tem = 0
                  while tem < len(next_keywords):
                    if keywords_lower[tem] in next_keywords[tem]:
                      marked_sequences.append((next_keywords[tem], 0))  # 关键词顺序相同，标记为0
                    else:
                      marked_sequences.append((next_keywords[tem], 1))  # 关键词顺序不同，标记为1
                    tem += 1
                  next_keywords = []  # 清空下一个关键词序列
                if len(keywords_lower) == len(third_keywords):
                  tem = 0
                  while tem < len(third_keywords):
                    if keywords_lower[tem] in third_keywords[tem]:
                      marked_sequences.append((third_keywords[tem], 0))
                    else:
                      marked_sequences.append((third_keywords[tem], 1))
                    tem += 1
                  third_keywords = []  # 清空第三个关键词序列
                if len(keywords_lower) == len(forth_keywords):
                  tem = 0
                  while tem < len(forth_keywords):
                    if keywords_lower[tem] in forth_keywords[tem]:
                      marked_sequences.append((forth_keywords[tem], 0))
                    else:
                      marked_sequences.append((forth_keywords[tem], 1))
                    tem += 1
                  forth_keywords = []  # 清空第四个关键词序列
                if len(keywords_lower) == len(fifth_keywords):
                  tem = 0
                  while tem < len(fifth_keywords):
                    if keywords_lower[tem] in fifth_keywords[tem]:
                      marked_sequences.append((fifth_keywords[tem], 0))
                    else:
                      marked_sequences.append((fifth_keywords[tem], 1))
                    tem += 1
                  fifth_keywords = []  # 清空第五个关键词序列
                if len(keywords_lower) == len(sixth_keywords):
                  tem = 0
                  while tem < len(sixth_keywords):
                    if keywords_lower[tem] in sixth_keywords[tem]:
                      marked_sequences.append((sixth_keywords[tem], 0))
                    else:
                      marked_sequences.append((sixth_keywords[tem], 1))
                    tem += 1
                  sixth_keywords = []  # 清空第六个关键词序列
                if len(keywords_lower) == len(seventh_keywords):
                  tem = 0
                  while tem < len(seventh_keywords):
                    if keywords_lower[tem] in seventh_keywords[tem]:
                      marked_sequences.append((seventh_keywords[tem], 0))
                    else:
                      marked_sequences.append((seventh_keywords[tem], 1))
                    tem += 1
                  seventh_keywords = []  # 清空第七个关键词序列
                if len(keywords_lower) == len(eighth_keywords):
                  tem = 0
                  while tem < len(eighth_keywords):
                    if keywords_lower[tem] in eighth_keywords[tem]:
                      marked_sequences.append((eighth_keywords[tem], 0))
                    else:
                      marked_sequences.append((eighth_keywords[tem], 1))
                    tem += 1
                  eighth_keywords = []  # 清空第八个关键词序列

                if word in keywords_lower and word not in id_keywords1:
                    current_keywords.append(data_lower)
                    id_keywords1.append(word)
                if word in keywords_lower and word in id_keywords1 and word not in id_keywords2:
                    next_keywords.append(data_lower)
                    id_keywords2.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word not in id_keywords3:
                    third_keywords.append(data_lower)
                    id_keywords3.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word not in id_keywords4:
                    forth_keywords.append(data_lower)
                    id_keywords4.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word in id_keywords4 and word not in id_keywords5:
                    fifth_keywords.append(data_lower)
                    id_keywords5.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word in id_keywords4 and word in id_keywords5 and word not in id_keywords6:
                    sixth_keywords.append(data_lower)
                    id_keywords6.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word in id_keywords4 and word in id_keywords5 and word in id_keywords6 and word not in id_keywords7:
                    seventh_keywords.append(data_lower)
                    id_keywords7.append(word)
                if word in keywords_lower and word in id_keywords1 and word in id_keywords2 and word in id_keywords3 and word in id_keywords4 and word in id_keywords5 and word in id_keywords6 and word in id_keywords7 and word not in id_keywords8:
                    eighth_keywords.append(data_lower)
                    id_keywords8.append(word)
    return marked_sequences

# 示例数据
file_path = '/content/sample_data/diag_log_20210716_150057_f634e5a31bf277bd6ad32a90ccc407e5_Xiaomi-Mi10_46000.txt'
keywords = ["Authentication","Attach","Detach","Service","Identity"]
output_file = '/content/sample_data/marked_data1.txt'

marked_sequences = mark_sequence(file_path, keywords)

# 将标记后的信息写入到输出文件
with open(output_file, 'w') as file:
    for seq, label in marked_sequences:
        line = ' '.join(seq) + ' ' + str(label) + '\n'
        file.write(line)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 定义RNN模型
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(1, x.size(0), self.hidden_size)  # 初始化隐藏状态
        out, _ = self.rnn(x, h0)  # RNN前向传播
        out = self.fc(out[:, -1, :])  # 取最后一个时间步的输出
        return out

# 准备数据
def prepare_data(input_sequences, word_to_index):
    max_len = max(len(seq) for seq in input_sequences)
    input_tensor = torch.zeros(len(input_sequences), max_len, len(word_to_index))
    for i, seq in enumerate(input_sequences):
        for j, word in enumerate(seq):
            input_tensor[i, j, word_to_index[word]] = 1
    return input_tensor

# 从txt文件读取数据并进行清洗
def read_and_clean_data_from_txt(file_path, keywords):
    input_sequences = []
    labels = []
    with open(file_path, 'r') as file:
        for line in file:
            data = line.strip().split()
            if len(data) < 2:
                continue  # 忽略不完整的数据行
            # 检查序列中是否包含关键字，若包含则保留
            if any(word.lower() in keywords for word in data[:-1]):
                input_sequences.append(data[:-1])
                if data[-1].isdigit():  # 检查最后一个元素是否是整数，作为标签
                    labels.append(int(data[-1]))
                else:
                    # 处理非整数标签
                    pass
    return input_sequences, labels
import os

# 指定目录路径
directory_path = '/content/sample_data/data'

# 列出目录中的所有文件
files = os.listdir(directory_path)
# 示例数据
#file_path = '/content/sample_data/data/marked_data2.txt'  # 修改为你的文件路径
keywords = {"rrcconnectionreconfiguration", "rrcconnectionreconfigurationcomplete",
            "ulinformationtransfer", "rrcconnectionrequest", "rrcconnectionsetup", "rrcconnectionsetupcomplete",
            "dlinformation transfer", "ulinformation transfer", "securitymodecommand",
            "securitymodecomplete", "uecapabilityenquiry", "uecapabilityinformation"}
for file_path in files:
  input_sequences, labels = read_and_clean_data_from_txt("/content/sample_data/data/"+file_path, keywords)

# 构建词汇表和标签
unique_words = set(word for seq in input_sequences for word in seq)
word_to_index = {word: i for i, word in enumerate(unique_words)}

# 训练模型
def train_model(model, input_sequences, labels, word_to_index, hidden_size, output_size, num_epochs=100):
    model.train()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    input_tensor = prepare_data(input_sequences, word_to_index)
    labels_tensor = torch.tensor(labels, dtype=torch.long)  # 使用从文件中读取的标签
    for epoch in range(num_epochs):
        optimizer.zero_grad()
        output = model(input_tensor)
        loss = criterion(output, labels_tensor)
        loss.backward()
        optimizer.step()
        if epoch % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

hidden_size = 16  # 隐藏层大小
output_size = 2  # 输出大小，二分类

# 创建和训练模型
model = RNN(len(unique_words), hidden_size, output_size)
train_model(model, input_sequences, labels, word_to_index, hidden_size, output_size, num_epochs=100)
# Out:
# Epoch [1/100], Loss: 0.6161
# Epoch [11/100], Loss: 0.5480
# Epoch [21/100], Loss: 0.4912
# Epoch [31/100], Loss: 0.4496
# Epoch [41/100], Loss: 0.4093
# Epoch [51/100], Loss: 0.3491
# Epoch [61/100], Loss: 0.2605
# Epoch [71/100], Loss: 0.1567
# Epoch [81/100], Loss: 0.0775
# Epoch [91/100], Loss: 0.0400

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 定义RNN模型
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(1, x.size(0), self.hidden_size)  # 初始化隐藏状态
        out, _ = self.rnn(x, h0)  # RNN前向传播
        out = self.fc(out[:, -1, :])  # 取最后一个时间步的输出
        return out

# 准备数据
def prepare_data(input_sequences, word_to_index):
    max_len = max(len(seq) for seq in input_sequences)
    input_tensor = torch.zeros(len(input_sequences), max_len, len(word_to_index))
    for i, seq in enumerate(input_sequences):
        for j, word in enumerate(seq):
            input_tensor[i, j, word_to_index[word]] = 1
    return input_tensor

# 从txt文件读取数据并进行清洗
def read_and_clean_data_from_txt(file_path, keywords):
    input_sequences = []
    labels = []
    with open(file_path, 'r') as file:
        for line in file:
            data = line.strip().split()
            if len(data) < 2:
                continue  # 忽略不完整的数据行
            # 检查序列中是否包含关键字，若包含则保留
            if any(word.lower() in keywords for word in data[:-1]):
                input_sequences.append(data[:-1])
                if data[-1].isdigit():  # 检查最后一个元素是否是整数，作为标签
                    labels.append(int(data[-1]))
                else:
                    # 处理非整数标签
                    pass
    return input_sequences, labels
import os

# 指定目录路径
directory_path = '/content/sample_data/data'

# 列出目录中的所有文件
files = os.listdir(directory_path)
# 示例数据
#file_path = '/content/sample_data/data/marked_data2.txt'  # 修改为你的文件路径
keywords = ["authentication","attach","detach","service","identity"]
for file_path in files:
  input_sequences, labels = read_and_clean_data_from_txt("/content/sample_data/data/"+file_path, keywords)

# 构建词汇表和标签
unique_words = set(word for seq in input_sequences for word in seq)
word_to_index = {word: i for i, word in enumerate(unique_words)}

# 训练模型
def train_model(model, input_sequences, labels, word_to_index, hidden_size, output_size, num_epochs=100):
    model.train()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    input_tensor = prepare_data(input_sequences, word_to_index)
    labels_tensor = torch.tensor(labels, dtype=torch.long)  # 使用从文件中读取的标签
    for epoch in range(num_epochs):
        optimizer.zero_grad()
        output = model(input_tensor)
        loss = criterion(output, labels_tensor)
        loss.backward()
        optimizer.step()
        if epoch % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

hidden_size = 16  # 隐藏层大小
output_size = 2  # 输出大小，二分类

# 创建和训练模型
model = RNN(len(unique_words), hidden_size, output_size)
train_model(model, input_sequences, labels, word_to_index, hidden_size, output_size, num_epochs=100)
# Out:
# Epoch [1/100], Loss: 0.6897
# Epoch [11/100], Loss: 0.6481
# Epoch [21/100], Loss: 0.6043
# Epoch [31/100], Loss: 0.5320
# Epoch [41/100], Loss: 0.3936
# Epoch [51/100], Loss: 0.2365
# Epoch [61/100], Loss: 0.1362
# Epoch [71/100], Loss: 0.0823
# Epoch [81/100], Loss: 0.0540
# Epoch [91/100], Loss: 0.0381

# %%
# 保存模型
torch.save(model.state_dict(), '/content/sample_data/rnn_model.pth')

# %%
# 从txt文件读取数据并进行清洗
def read_and_clean_data_from_txt(file_path, keywords):
    input_sequences = []
    with open(file_path, 'r') as file:
        for line in file:
            data = line.strip().split()
            if len(data) < 2:
                continue  # 忽略不完整的数据行
            # 检查消息中是否包含关键词
            if any(word.lower() in keywords for word in data[:-1]):
                input_sequences.append([word.lower() for word in data[:-1]])  # 将消息转换为小写并保留关键词序列
    return input_sequences

# 示例数据
file_path = '/content/sample_data/diag_log_20210716_142408_f634e5a31bf277bd6ad32a90ccc407e5_Xiaomi-Mi10_46000.txt'  # 修改为你的文件路径
output_file = '/content/sample_data/cleaned_data1.txt'  # 输出文件路径
keywords = ["rrcconnectionreconfiguration", "rrcconnectionreconfigurationcomplete",
            "ulinformationtransfer", "rrcconnectionrequest", "rrcconnectionsetup", "rrcconnectionsetupcomplete",
            "securitymodecommand",
            "securitymodecomplete", "uecapabilityenquiry", "uecapabilityinformation"]
input_sequences = read_and_clean_data_from_txt(file_path, keywords)

# 将处理后的信息保存为txt文件
with open(output_file, 'w') as file:
    for seq in input_sequences:
        line = ' '.join(seq) + '\n'
        file.write(line)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-cee7e9dd242e> in <cell line: 21>()
#      19             "securitymodecommand",
#      20             "securitymodecomplete", "uecapabilityenquiry", "uecapabilityinformation"]
# ---> 21 input_sequences = read_and_clean_data_from_txt(file_path, keywords)
#      22
#      23 # 将处理后的信息保存为txt文件
#
# <ipython-input-4-cee7e9dd242e> in read_and_clean_data_from_txt(file_path, keywords)
#       8                 continue  # 忽略不完整的数据行
#       9             # 检查消息中是否包含关键词
# ---> 10             if any(word.lower() in keywords for word in data[:-1]):
#      11                 input_sequences.append([word.lower() for word in data[:-1]])  # 将消息转换为小写并保留关键词序列
#      12     return input_sequences
#
# <ipython-input-4-cee7e9dd242e> in <genexpr>(.0)
#       8                 continue  # 忽略不完整的数据行
#       9             # 检查消息中是否包含关键词
# ---> 10             if any(word.lower() in keywords for word in data[:-1]):
#      11                 input_sequences.append([word.lower() for word in data[:-1]])  # 将消息转换为小写并保留关键词序列
#      12     return input_sequences
#
# KeyboardInterrupt:

# %%
# 从txt文件读取数据并进行清洗
def read_and_clean_data_from_txt(file_path, keywords):
    input_sequences = []
    with open(file_path, 'r') as file:
        for line in file:
            data = line.strip().split()
            if len(data) < 2:
                continue  # 忽略不完整的数据行
            # 检查消息中是否包含关键词
            if any(word.lower() in keywords for word in data[:-1]):
                input_sequences.append([word.lower() for word in data[:-1]])  # 将消息转换为小写并保留关键词序列
    return input_sequences

# 示例数据
file_path = '/content/sample_data/diag_log_20210716_150057_f634e5a31bf277bd6ad32a90ccc407e5_Xiaomi-Mi10_46000.txt'  # 修改为你的文件路径
output_file = '/content/sample_data/cleaned_data1.txt'  # 输出文件路径
keywords = ["authentication","attach","detach","service","identity"]
input_sequences = read_and_clean_data_from_txt(file_path, keywords)

# 将处理后的信息保存为txt文件
with open(output_file, 'w') as file:
    for seq in input_sequences:
        line = ' '.join(seq) + '\n'
        file.write(line)

# %%
from os import write
def mark_sequence(file_path, keywords):
    marked_sequences = []  # 存储标记后的信息序列
    keywords_lower = [word.lower() for word in keywords]
    current_keywords = []  # 存储当前已经出现的关键词序列
    next_keywords = []  # 存储下一个关键词序列
    third_keywords = []  # 存储第三个关键词序列
    forth_keywords = []  # 存储第四个关键词序列
    fifth_keywords = []  # 存储第五个关键词序列
    sixth_keywords = []  # 存储第六个关键词序列
    seventh_keywords = []  # 存储第七个关键词序列
    eighth_keywords = []  # 存储第八个关键词序列
    #ninth_keywords = []  # 存储第九个关键词序列
    #tenth_keywords = []  # 存储第十个关键词序列
    with open(file_path, 'r') as file:
        for line in file:
            words = line.strip().split()  # 按空格分割每行信息
            data_lower = [word.lower() for word in words]  # 将单词转换为小写
            for word in data_lower:
                if len(keywords_lower) == len(current_keywords):
                  marked_sequences.append(words)  # 关键词顺序不同，标记为1
                  current_keywords = []  # 清空当前关键词序列
                if len(keywords_lower) == len(next_keywords):
                  marked_sequences.append(words)  # 关键词顺序不同，标记为1
                  next_keywords = []  # 清空下一个关键词序列
                if len(keywords_lower) == len(third_keywords):
                  marked_sequences.append(words)
                  third_keywords = []  # 清空第三个关键词序列
                if len(keywords_lower) == len(forth_keywords):
                  marked_sequences.append(words)
                  forth_keywords = []  # 清空第四个关键词序列
                if len(keywords_lower) == len(fifth_keywords):
                  marked_sequences.append(words)
                  fifth_keywords = []  # 清空第五个关键词序列
                if len(keywords_lower) == len(sixth_keywords):
                  marked_sequences.append(words)
                  sixth_keywords = []  # 清空第六个关键词序列
                if len(keywords_lower) == len(seventh_keywords):
                  marked_sequences.append(words)
                  seventh_keywords = []  # 清空第七个关键词序列
                if len(keywords_lower) == len(eighth_keywords):
                  marked_sequences.append(words)
                  eighth_keywords = []  # 清空第八个关键词序列

                if word in keywords_lower and word not in current_keywords:
                    current_keywords.append(words)
                if word in keywords_lower and word in current_keywords and word not in next_keywords:
                    next_keywords.append(words)
                if word in keywords_lower and word in current_keywords and word in next_keywords and word not in third_keywords:
                    third_keywords.append(words)
                if word in keywords_lower and word in current_keywords and word in next_keywords and word in third_keywords and word not in forth_keywords:
                    forth_keywords.append(words)
                if word in keywords_lower and word in current_keywords and word in next_keywords and word in third_keywords and word in forth_keywords and word not in fifth_keywords:
                    fifth_keywords.append(words)
                if word in keywords_lower and word in current_keywords and word in next_keywords and word in third_keywords and word in forth_keywords and word in fifth_keywords and word not in sixth_keywords:
                    sixth_keywords.append(words)
                if word in keywords_lower and word in current_keywords and word in next_keywords and word in third_keywords and word in forth_keywords and word in fifth_keywords and word in sixth_keywords and word not in seventh_keywords:
                    seventh_keywords.append(words)
                if word in keywords_lower and word in current_keywords and word in next_keywords and word in third_keywords and word in forth_keywords and word in fifth_keywords and word in sixth_keywords and word in seventh_keywords and word not in eighth_keywords:
                    eighth_keywords.append(words)
    return marked_sequences

# 示例数据
file_path = '/content/sample_data/diag_log_20210716_150057_f634e5a31bf277bd6ad32a90ccc407e5_Xiaomi-Mi10_46000.txt'
keywords = ["RRCConnectionReconfiguration", "RRCConnectionReconfigurationComplete",
            "ULInformationTransfer", "RRCConnectionRequest", "RRCConnectionSetup", "RRCConnectionSetupComplete",
            "SecurityModeCommand",
            "SecurityModeComplete", "UECapabilityEnquiry", "UECapabilityInformation"]
output_file = '/content/sample_data/cleaned_data.txt'

marked_sequences = mark_sequence(file_path, keywords)

# 将标记后的信息写入到输出文件
with open(output_file, 'w') as file:
    for seq in marked_sequences:
        line = ' '.join(seq) + ' ' + '\n'
        file.write(line)

# %%
def read_txt_file(file_path):
    content_list = []
    with open(file_path, 'r') as file:
        for line in file:
            content_list.append(line.strip())  # 将每一行的内容添加到列表中，并去除换行符
    return content_list

# 指定txt文件路径
file_path = '/content/sample_data/cleaned_data1.txt'  # 替换为你的txt文件路径

# 读取txt文件内容并存储在列表中
content_list = read_txt_file(file_path)

# %%
def read_txt_file(file_path):
    content_list = []
    with open(file_path, 'r') as file:
        for line in file:
            content_list.append(line.strip())  # 将每一行的内容添加到列表中，并去除换行符
    return content_list

# 指定txt文件路径
file_path = '/content/sample_data/cleaned_data1.txt'  # 替换为你的txt文件路径

# 读取txt文件内容并存储在列表中
content_list = read_txt_file(file_path)
import torch
import torch.nn as nn

# 加载模型
model_path = '/content/sample_data/rnn_model.pth'
model = RNN(len(unique_words), hidden_size, output_size)
model.load_state_dict(torch.load(model_path))
model.eval()

# 准备输入数据的函数
def prepare_input_data(file_path, word_to_index):
    input_sequences = []
    with open(file_path, 'r') as file:
        for line in file:
            words = line.strip().split()
            input_sequences.append([word_to_index[word.lower()] for word in words if word.lower() in word_to_index])
    max_len = max(len(seq) for seq in input_sequences)
    input_tensor = torch.zeros(len(input_sequences), max_len, len(word_to_index))
    for i, seq in enumerate(input_sequences):
        for j, word_index in enumerate(seq):
            input_tensor[i, j, word_index] = 1
    return input_tensor

# 输入文件路径
input_file_path = '/content/sample_data/cleaned_data1.txt'

# 准备输入数据
input_tensor = prepare_input_data(input_file_path, word_to_index)

# 执行推理
with torch.no_grad():
    output = model(input_tensor)

# 处理输出
# 这里假设模型输出的是二分类的预测结果，可以根据实际情况进行后处理
predicted_labels = torch.argmax(output, dim=1)
for i, label in enumerate(predicted_labels):
    if label.item() == 1:
        print(f"{content_list[i]} is out of order")
    else:
        print(f"{content_list[i]} is in order")


# 打印预测结果
print(predicted_labels)

# 创建一个列表来存储输出结果的字符串
output_strings = []

for i, label in enumerate(predicted_labels):
    if label.item() == 1:
        output_strings.append(f"{content_list[i]} is out of order")
    else:
        output_strings.append(f"{content_list[i]} is in order")

# 指定保存结果的文件路径
output_file_path = 'output_results.txt'

# 将输出结果写入txt文件
with open(output_file_path, 'w') as file:
    for line in output_strings:
        file.write(line + '\n')
# Out:
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x19e1e023" size="4" pos="1" show="0x19e1e023" value="19e1e023" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="7" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="25" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xfd0c0344" size="4" pos="1" show="0xfd0c0344" value="fd0c0344" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication response (0x53)" size="1" pos="7" show="83" value="53" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x813f0e1c" size="4" pos="1" show="0x813f0e1c" value="813f0e1c" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x6ee6bf6a" size="4" pos="1" show="0x6ee6bf6a" value="6ee6bf6a" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x6f6bcc26" size="4" pos="1" show="0x6f6bcc26" value="6f6bcc26" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach accept (0x42)" size="1" pos="7" show="66" value="42" is in order
# <field name="nas_eps.emm.eps_attach_result" showname=".... .010 = attach result: combined eps/imsi attach (2)" size="1" pos="8" show="2" value="02" is in order
# <field name="" show="tracking area identity list - tai list" size="7" pos="10" is out of order
# <field name="nas_eps.bearer_id" showname="0101 .... = eps bearer identity: eps bearer identity value 5 (5)" size="1" pos="19" show="5" value="5" unmaskedvalue="52" is out of order
# <field name="nas_eps.esm.qci" showname="quality of service class identifier (qci): qci 8 (8)" size="1" pos="23" show="8" value="08" is in order
# <field name="" show="quality of service - negotiated qos" size="18" pos="67" is in order
# <field name="gsm_a.gm.sm.qos.delay_cls" showname="..01 1... = quality of service delay class: delay class 3 (3)" size="1" pos="69" show="3" value="3" unmaskedvalue="1b" is out of order
# <field name="" show="llc service access point identifier - negotiated llc sapi" size="2" pos="85" is in order
# <field name="" show="eps mobile identity - guti" size="13" pos="170" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="172" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="mobile identity - ms identity - tmsi/p-tmsi (0xa2f19d93)" size="7" pos="189" is in order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="191" show="0" value="0" unmaskedvalue="f4" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .100 = mobile identity type: tmsi/p-tmsi/m-tmsi (4)" size="1" pos="191" show="4" value="4" unmaskedvalue="f4" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="198" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x99bf920c" size="4" pos="1" show="0x99bf920c" value="99bf920c" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach complete (0x43)" size="1" pos="7" show="67" value="43" is out of order
# <field name="nas_eps.bearer_id" showname="0101 .... = eps bearer identity: eps bearer identity value 5 (5)" size="1" pos="10" show="5" value="5" unmaskedvalue="52" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x4ab98a39" size="4" pos="1" show="0x4ab98a39" value="4ab98a39" is in order
# <field name="nas_eps.bearer_id" showname="0110 .... = eps bearer identity: eps bearer identity value 6 (6)" size="1" pos="6" show="6" value="6" unmaskedvalue="62" is out of order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="1" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="19" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication response (0x53)" size="1" pos="1" show="83" value="53" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xaecb1f23" size="4" pos="1" show="0xaecb1f23" value="aecb1f23" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x484ce5e4" size="4" pos="1" show="0x484ce5e4" value="484ce5e4" is in order
# <field name="" show="mobile identity - imeisv - imeisv (8683670482226000)" size="11" pos="8" is in order
# <field name="gsm_a.id_dig_1" showname="1000 .... = identity digit 1: 8" size="1" pos="10" show="8" value="8" unmaskedvalue="83" is out of order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="83" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .011 = mobile identity type: imeisv (3)" size="1" pos="10" show="3" value="3" unmaskedvalue="83" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x613bba86" size="4" pos="1" show="0x613bba86" value="613bba86" is in order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="6" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x1071a33b" size="4" pos="1" show="0x1071a33b" value="1071a33b" is in order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="6" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="19" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="47" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco.pdu_session_id" showname="pdu session identity: pdu session identity value 1 (1)" size="1" pos="112" show="1" value="01" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xd5de9ddb" size="4" pos="1" show="0xd5de9ddb" value="d5de9ddb" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach request (0x41)" size="1" pos="7" show="65" value="41" is out of order
# <field name="nas_eps.emm.eps_att_type" showname=".... .010 = eps attach type: combined eps/imsi attach (2)" size="1" pos="8" show="2" value="12" is out of order
# <field name="nas_eps.emm.odd_even" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="10" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="25" show="0" value="0" unmaskedvalue="80" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="28" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="52" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x1b543bfa" size="4" pos="1" show="0x1b543bfa" value="1b543bfa" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="7" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="25" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xa249ff34" size="4" pos="1" show="0xa249ff34" value="a249ff34" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication response (0x53)" size="1" pos="7" show="83" value="53" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xb9b1b763" size="4" pos="1" show="0xb9b1b763" value="b9b1b763" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xc49fa3bc" size="4" pos="1" show="0xc49fa3bc" value="c49fa3bc" is in order
# <field name="" show="mobile identity - imeisv - imeisv (8683670482226000)" size="11" pos="8" is in order
# <field name="gsm_a.id_dig_1" showname="1000 .... = identity digit 1: 8" size="1" pos="10" show="8" value="8" unmaskedvalue="83" is out of order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="83" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .011 = mobile identity type: imeisv (3)" size="1" pos="10" show="3" value="3" unmaskedvalue="83" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xc46a4dba" size="4" pos="1" show="0xc46a4dba" value="c46a4dba" is in order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="6" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xb7ee74b0" size="4" pos="1" show="0xb7ee74b0" value="b7ee74b0" is in order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="6" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="19" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="47" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco.pdu_session_id" showname="pdu session identity: pdu session identity value 1 (1)" size="1" pos="112" show="1" value="01" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x68b27416" size="4" pos="1" show="0x68b27416" value="68b27416" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach reject (0x44)" size="1" pos="7" show="68" value="44" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="12" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.esm.cause" showname="cause: user authentication failed (29)" size="1" pos="15" show="29" value="1d" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xdb7caf03" size="4" pos="1" show="0xdb7caf03" value="db7caf03" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach request (0x41)" size="1" pos="7" show="65" value="41" is out of order
# <field name="nas_eps.emm.eps_att_type" showname=".... .010 = eps attach type: combined eps/imsi attach (2)" size="1" pos="8" show="2" value="22" is out of order
# <field name="nas_eps.emm.odd_even" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="10" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="25" show="0" value="0" unmaskedvalue="80" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="28" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="52" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="1" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="19" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x0ebcee73" size="4" pos="1" show="0x0ebcee73" value="0ebcee73" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication response (0x53)" size="1" pos="7" show="83" value="53" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x96fe7998" size="4" pos="1" show="0x96fe7998" value="96fe7998" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x8800c49a" size="4" pos="1" show="0x8800c49a" value="8800c49a" is in order
# <field name="" show="mobile identity - imeisv - imeisv (8683670482226000)" size="11" pos="8" is in order
# <field name="gsm_a.id_dig_1" showname="1000 .... = identity digit 1: 8" size="1" pos="10" show="8" value="8" unmaskedvalue="83" is out of order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="83" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .011 = mobile identity type: imeisv (3)" size="1" pos="10" show="3" value="3" unmaskedvalue="83" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x2bcbe276" size="4" pos="1" show="0x2bcbe276" value="2bcbe276" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach request (0x41)" size="1" pos="7" show="65" value="41" is out of order
# <field name="nas_eps.emm.eps_att_type" showname=".... .010 = eps attach type: combined eps/imsi attach (2)" size="1" pos="8" show="2" value="12" is out of order
# <field name="nas_eps.emm.odd_even" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="10" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="25" show="0" value="0" unmaskedvalue="80" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="28" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="52" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="1" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="19" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x3344e469" size="4" pos="1" show="0x3344e469" value="3344e469" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x3ab38e7b" size="4" pos="1" show="0x3ab38e7b" value="3ab38e7b" is in order
# <field name="" show="mobile identity - imeisv - imeisv (8683670482226000)" size="11" pos="8" is in order
# <field name="gsm_a.id_dig_1" showname="1000 .... = identity digit 1: 8" size="1" pos="10" show="8" value="8" unmaskedvalue="83" is out of order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="83" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .011 = mobile identity type: imeisv (3)" size="1" pos="10" show="3" value="3" unmaskedvalue="83" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xed55dace" size="4" pos="1" show="0xed55dace" value="ed55dace" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach reject (0x44)" size="1" pos="7" show="68" value="44" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="12" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.esm.cause" showname="cause: user authentication failed (29)" size="1" pos="15" show="29" value="1d" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x59a018d3" size="4" pos="1" show="0x59a018d3" value="59a018d3" is in order
# <field name="" show="eps mobile identity - guti" size="13" pos="11" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="13" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="tracking area identity list" size="8" pos="24" is in order
# <field name="" show="mobile identity - ms identity - tmsi/p-tmsi (0xa8ecbe13)" size="7" pos="42" is in order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="44" show="0" value="0" unmaskedvalue="f4" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .100 = mobile identity type: tmsi/p-tmsi/m-tmsi (4)" size="1" pos="44" show="4" value="4" unmaskedvalue="f4" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="51" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xd3fa48b7" size="4" pos="1" show="0xd3fa48b7" value="d3fa48b7" is in order
# <field name="nas_eps.security_header_type" showname="1100 .... = security header type: security header for the service request message (12)" size="1" pos="0" show="12" value="c" unmaskedvalue="c7" is out of order
# <field name="" show="short mac - message authentication code (short)" size="2" pos="2" is in order
# <field name="nas_eps.emm.short_mac" showname="message authentication code (short): 0xac60" size="2" pos="2" show="0x0000ac60" value="ac60" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: identity request (0x55)" size="1" pos="1" show="85" value="55" is out of order
# <field name="nas_eps.emm.id_type2" showname=".... 0001 = identity type 2: imsi (1)" size="1" pos="2" show="1" value="01" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x7a86f98f" size="4" pos="1" show="0x7a86f98f" value="7a86f98f" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: identity response (0x56)" size="1" pos="7" show="86" value="56" is out of order
# <field name="" show="mobile identity - imsi (460025108562188)" size="9" pos="8" is in order
# <field name="gsm_a.id_dig_1" showname="0100 .... = identity digit 1: 4" size="1" pos="9" show="4" value="4" unmaskedvalue="49" is in order
# <field name="gsm_a.oddevenind" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="9" show="1" value="1" unmaskedvalue="49" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .001 = mobile identity type: imsi (1)" size="1" pos="9" show="1" value="1" unmaskedvalue="49" is in order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x67daf110" size="4" pos="1" show="0x67daf110" value="67daf110" is in order
# <field name="" show="eps mobile identity - old guti" size="12" pos="9" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="29" show="0" value="0" unmaskedvalue="90" is out of order
# <field name="" show="tracking area identity - last visited registered tai" size="6" pos="30" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="59" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x61945359" size="4" pos="1" show="0x61945359" value="61945359" is in order
# <field name="" show="eps mobile identity - guti" size="13" pos="11" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="13" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="tracking area identity list" size="8" pos="24" is in order
# <field name="" show="mobile identity - ms identity - tmsi/p-tmsi (0xabedcd93)" size="7" pos="42" is in order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="44" show="0" value="0" unmaskedvalue="f4" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .100 = mobile identity type: tmsi/p-tmsi/m-tmsi (4)" size="1" pos="44" show="4" value="4" unmaskedvalue="f4" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="51" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x913e0ff5" size="4" pos="1" show="0x913e0ff5" value="913e0ff5" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x04c04ea0" size="4" pos="1" show="0x04c04ea0" value="04c04ea0" is in order
# <field name="" show="eps mobile identity - guti" size="13" pos="11" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="13" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="tracking area identity list" size="8" pos="24" is in order
# <field name="" show="mobile identity - ms identity - tmsi/p-tmsi (0xaeed142b)" size="7" pos="42" is in order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="44" show="0" value="0" unmaskedvalue="f4" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .100 = mobile identity type: tmsi/p-tmsi/m-tmsi (4)" size="1" pos="44" show="4" value="4" unmaskedvalue="f4" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="51" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x8472f954" size="4" pos="1" show="0x8472f954" value="8472f954" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x84bc9cd1" size="4" pos="1" show="0x84bc9cd1" value="84bc9cd1" is in order
# <field name="" show="eps mobile identity - old guti" size="12" pos="9" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="29" show="0" value="0" unmaskedvalue="90" is out of order
# <field name="" show="tracking area identity - last visited registered tai" size="6" pos="30" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="59" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x74e86900" size="4" pos="1" show="0x74e86900" value="74e86900" is in order
# <field name="" show="eps mobile identity - old guti" size="12" pos="9" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="29" show="0" value="0" unmaskedvalue="90" is out of order
# <field name="" show="tracking area identity - last visited registered tai" size="6" pos="30" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="59" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x60404689" size="4" pos="1" show="0x60404689" value="60404689" is in order
# <field name="" show="eps mobile identity - old guti" size="12" pos="9" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="29" show="0" value="0" unmaskedvalue="90" is out of order
# <field name="" show="tracking area identity - last visited registered tai" size="6" pos="30" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="59" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.security_header_type" showname="1100 .... = security header type: security header for the service request message (12)" size="1" pos="0" show="12" value="c" unmaskedvalue="c7" is out of order
# <field name="" show="short mac - message authentication code (short)" size="2" pos="2" is in order
# <field name="nas_eps.emm.short_mac" showname="message authentication code (short): 0x43a2" size="2" pos="2" show="0x000043a2" value="43a2" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xe17db352" size="4" pos="1" show="0xe17db352" value="e17db352" is in order
# <field name="" show="eps mobile identity - old guti" size="12" pos="9" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="29" show="0" value="0" unmaskedvalue="90" is out of order
# <field name="" show="tracking area identity - last visited registered tai" size="6" pos="30" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="59" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x0b3e58fc" size="4" pos="1" show="0x0b3e58fc" value="0b3e58fc" is in order
# <field name="" show="eps mobile identity - guti" size="13" pos="11" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="13" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="tracking area identity list" size="8" pos="24" is in order
# <field name="" show="mobile identity - ms identity - tmsi/p-tmsi (0x3eb91db4)" size="7" pos="42" is in order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="44" show="0" value="0" unmaskedvalue="f4" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .100 = mobile identity type: tmsi/p-tmsi/m-tmsi (4)" size="1" pos="44" show="4" value="4" unmaskedvalue="f4" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="51" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x2c8b487e" size="4" pos="1" show="0x2c8b487e" value="2c8b487e" is in order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x8a02a047" size="4" pos="1" show="0x8a02a047" value="8a02a047" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="7" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="25" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xdb579a59" size="4" pos="1" show="0xdb579a59" value="db579a59" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication response (0x53)" size="1" pos="7" show="83" value="53" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x9c32b3b8" size="4" pos="1" show="0x9c32b3b8" value="9c32b3b8" is in order
# <field name="" show="eps mobile identity - guti" size="13" pos="11" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="13" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="tracking area identity list" size="8" pos="24" is in order
# <field name="" show="mobile identity - ms identity - tmsi/p-tmsi (0xb9ef43a3)" size="7" pos="42" is in order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="44" show="0" value="0" unmaskedvalue="f4" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .100 = mobile identity type: tmsi/p-tmsi/m-tmsi (4)" size="1" pos="44" show="4" value="4" unmaskedvalue="f4" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="51" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xd424d97c" size="4" pos="1" show="0xd424d97c" value="d424d97c" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xc37f4354" size="4" pos="1" show="0xc37f4354" value="c37f4354" is in order
# <field name="" show="eps mobile identity - old guti" size="12" pos="9" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="29" show="0" value="0" unmaskedvalue="90" is out of order
# <field name="" show="tracking area identity - last visited registered tai" size="6" pos="30" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="59" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x61652abf" size="4" pos="15" show="0x61652abf" value="61652abf" is out of order
# <field name="" show="eps mobile identity - old guti" size="12" pos="23" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="24" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="43" show="0" value="0" unmaskedvalue="90" is out of order
# <field name="" show="tracking area identity - last visited registered tai" size="6" pos="44" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="73" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x1f7a14c7" size="4" pos="1" show="0x1f7a14c7" value="1f7a14c7" is in order
# <field name="" show="eps mobile identity - guti" size="13" pos="11" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="13" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="tracking area identity list" size="8" pos="24" is in order
# <field name="" show="mobile identity - ms identity - tmsi/p-tmsi (0xec137b)" size="7" pos="42" is in order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="44" show="0" value="0" unmaskedvalue="f4" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .100 = mobile identity type: tmsi/p-tmsi/m-tmsi (4)" size="1" pos="44" show="4" value="4" unmaskedvalue="f4" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="51" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x6fbe45f4" size="4" pos="1" show="0x6fbe45f4" value="6fbe45f4" is in order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x2b78fead" size="4" pos="1" show="0x2b78fead" value="2b78fead" is in order
# <field name="" show="eps mobile identity - guti" size="13" pos="11" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="13" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="tracking area identity list" size="8" pos="24" is in order
# <field name="" show="mobile identity - ms identity - tmsi/p-tmsi (0xcee482b)" size="7" pos="42" is in order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="44" show="0" value="0" unmaskedvalue="f4" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .100 = mobile identity type: tmsi/p-tmsi/m-tmsi (4)" size="1" pos="44" show="4" value="4" unmaskedvalue="f4" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="51" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x24f55205" size="4" pos="1" show="0x24f55205" value="24f55205" is in order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="956" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: identity request (0x55)" size="1" pos="1" show="85" value="55" is out of order
# <field name="nas_eps.emm.id_type2" showname=".... 0001 = identity type 2: imsi (1)" size="1" pos="2" show="1" value="01" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: identity response (0x56)" size="1" pos="1" show="86" value="56" is out of order
# <field name="" show="mobile identity - imsi (310260974001859)" size="9" pos="2" is in order
# <field name="gsm_a.id_dig_1" showname="0011 .... = identity digit 1: 3" size="1" pos="3" show="3" value="3" unmaskedvalue="39" is in order
# <field name="gsm_a.oddevenind" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="3" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .001 = mobile identity type: imsi (1)" size="1" pos="3" show="1" value="1" unmaskedvalue="39" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="1" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="19" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication response (0x53)" size="1" pos="1" show="83" value="53" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x7725a027" size="4" pos="1" show="0x7725a027" value="7725a027" is in order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="6" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xb093a018" size="4" pos="1" show="0xb093a018" value="b093a018" is in order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="6" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="19" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="47" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco.pdu_session_id" showname="pdu session identity: pdu session identity value 1 (1)" size="1" pos="112" show="1" value="01" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x4af1f2de" size="4" pos="1" show="0x4af1f2de" value="4af1f2de" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach reject (0x44)" size="1" pos="7" show="68" value="44" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="12" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.esm.cause" showname="cause: user authentication failed (29)" size="1" pos="15" show="29" value="1d" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x4c721a8f" size="4" pos="1" show="0x4c721a8f" value="4c721a8f" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach request (0x41)" size="1" pos="7" show="65" value="41" is out of order
# <field name="nas_eps.emm.eps_att_type" showname=".... .010 = eps attach type: combined eps/imsi attach (2)" size="1" pos="8" show="2" value="12" is out of order
# <field name="nas_eps.emm.odd_even" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="10" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="25" show="0" value="0" unmaskedvalue="80" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="28" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="52" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="956" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: identity request (0x55)" size="1" pos="1" show="85" value="55" is out of order
# <field name="nas_eps.emm.id_type2" showname=".... 0001 = identity type 2: imsi (1)" size="1" pos="2" show="1" value="01" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x6c6ba430" size="4" pos="1" show="0x6c6ba430" value="6c6ba430" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: identity response (0x56)" size="1" pos="7" show="86" value="56" is out of order
# <field name="" show="mobile identity - imsi (310260974001859)" size="9" pos="8" is in order
# <field name="gsm_a.id_dig_1" showname="0011 .... = identity digit 1: 3" size="1" pos="9" show="3" value="3" unmaskedvalue="39" is in order
# <field name="gsm_a.oddevenind" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="9" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .001 = mobile identity type: imsi (1)" size="1" pos="9" show="1" value="1" unmaskedvalue="39" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x9c4fa019" size="4" pos="1" show="0x9c4fa019" value="9c4fa019" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="7" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="25" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xdb5d5b1c" size="4" pos="1" show="0xdb5d5b1c" value="db5d5b1c" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication response (0x53)" size="1" pos="7" show="83" value="53" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xb4df744c" size="4" pos="1" show="0xb4df744c" value="b4df744c" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x0104f19b" size="4" pos="1" show="0x0104f19b" value="0104f19b" is in order
# <field name="" show="mobile identity - imeisv - imeisv (8683670482226000)" size="11" pos="8" is in order
# <field name="gsm_a.id_dig_1" showname="1000 .... = identity digit 1: 8" size="1" pos="10" show="8" value="8" unmaskedvalue="83" is out of order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="83" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .011 = mobile identity type: imeisv (3)" size="1" pos="10" show="3" value="3" unmaskedvalue="83" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xb16bd4d4" size="4" pos="1" show="0xb16bd4d4" value="b16bd4d4" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach request (0x41)" size="1" pos="7" show="65" value="41" is out of order
# <field name="nas_eps.emm.eps_att_type" showname=".... .010 = eps attach type: combined eps/imsi attach (2)" size="1" pos="8" show="2" value="22" is out of order
# <field name="nas_eps.emm.odd_even" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="10" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="25" show="0" value="0" unmaskedvalue="80" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="28" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="52" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xda38d0b2" size="4" pos="1" show="0xda38d0b2" value="da38d0b2" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="7" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="25" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x65429907" size="4" pos="1" show="0x65429907" value="65429907" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication response (0x53)" size="1" pos="7" show="83" value="53" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x6585dc04" size="4" pos="1" show="0x6585dc04" value="6585dc04" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x6fd8c254" size="4" pos="1" show="0x6fd8c254" value="6fd8c254" is in order
# ...
# <field name="" show="eps mobile identity - guti" size="13" pos="11" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="13" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="tracking area identity list" size="8" pos="24" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="38" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x99df1908" size="4" pos="1" show="0x99df1908" value="99df1908" is in order
# <field name="nas_eps.security_header_type" showname="1100 .... = security header type: security header for the service request message (12)" size="1" pos="0" show="12" value="c" unmaskedvalue="c7" is out of order
# <field name="" show="short mac - message authentication code (short)" size="2" pos="2" is in order
# <field name="nas_eps.emm.short_mac" showname="message authentication code (short): 0xfd8e" size="2" pos="2" show="0x0000fd8e" value="fd8e" is in order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.security_header_type" showname="1100 .... = security header type: security header for the service request message (12)" size="1" pos="0" show="12" value="c" unmaskedvalue="c7" is out of order
# <field name="" show="short mac - message authentication code (short)" size="2" pos="2" is in order
# <field name="nas_eps.emm.short_mac" showname="message authentication code (short): 0xc51e" size="2" pos="2" show="0x0000c51e" value="c51e" is in order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach request (0x41)" size="1" pos="1" show="65" value="41" is out of order
# <field name="nas_eps.emm.eps_att_type" showname=".... .010 = eps attach type: combined eps/imsi attach (2)" size="1" pos="2" show="2" value="72" is out of order
# <field name="nas_eps.emm.odd_even" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="4" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="19" show="0" value="0" unmaskedvalue="80" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="22" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="46" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication response (0x53)" size="1" pos="1" show="83" value="53" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x39146369" size="4" pos="1" show="0x39146369" value="39146369" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xf3fef501" size="4" pos="1" show="0xf3fef501" value="f3fef501" is in order
# <field name="" show="mobile identity - imeisv - imeisv (8683670482226000)" size="11" pos="8" is in order
# <field name="gsm_a.id_dig_1" showname="1000 .... = identity digit 1: 8" size="1" pos="10" show="8" value="8" unmaskedvalue="83" is out of order
# <field name="gsm_a.oddevenind" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="83" is out of order
# <field name="gsm_a.ie.mobileid.type" showname=".... .011 = mobile identity type: imeisv (3)" size="1" pos="10" show="3" value="3" unmaskedvalue="83" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xc0575701" size="4" pos="1" show="0xc0575701" value="c0575701" is in order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="6" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xb039fc77" size="4" pos="1" show="0xb039fc77" value="b039fc77" is in order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="6" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="19" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="47" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco.pdu_session_id" showname="pdu session identity: pdu session identity value 1 (1)" size="1" pos="112" show="1" value="01" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x5157389f" size="4" pos="1" show="0x5157389f" value="5157389f" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach reject (0x44)" size="1" pos="7" show="68" value="44" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="12" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.esm.cause" showname="cause: user authentication failed (29)" size="1" pos="15" show="29" value="1d" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x5d9792a5" size="4" pos="1" show="0x5d9792a5" value="5d9792a5" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach request (0x41)" size="1" pos="7" show="65" value="41" is out of order
# <field name="nas_eps.emm.eps_att_type" showname=".... .010 = eps attach type: combined eps/imsi attach (2)" size="1" pos="8" show="2" value="12" is out of order
# <field name="nas_eps.emm.odd_even" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="10" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="25" show="0" value="0" unmaskedvalue="80" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="28" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="52" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: authentication request (0x52)" size="1" pos="1" show="82" value="52" is out of order
# <field name="" show="authentication parameter autn (umts and eps authentication challenge) - eps challenge" size="17" pos="19" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x74252792" size="4" pos="1" show="0x74252792" value="74252792" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach reject (0x44)" size="1" pos="7" show="68" value="44" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="12" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.esm.cause" showname="cause: user authentication failed (29)" size="1" pos="15" show="29" value="1d" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x412ac864" size="4" pos="1" show="0x412ac864" value="412ac864" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach request (0x41)" size="1" pos="7" show="65" value="41" is out of order
# <field name="nas_eps.emm.eps_att_type" showname=".... .010 = eps attach type: combined eps/imsi attach (2)" size="1" pos="8" show="2" value="22" is out of order
# <field name="nas_eps.emm.odd_even" showname=".... 1... = odd/even indication: odd number of identity digits" size="1" pos="10" show="1" value="1" unmaskedvalue="39" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="25" show="0" value="0" unmaskedvalue="80" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="28" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="52" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xa6e91043" size="4" pos="1" show="0xa6e91043" value="a6e91043" is in order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="6" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="19" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco_pid" showname="protocol or container id: challenge handshake authentication protocol (0xc223)" size="2" pos="47" show="0x0000c223" is out of order
# <proto name="chap" showname="ppp challenge handshake authentication protocol" size="25" is out of order
# <field name="gsm_a.gm.sm.pco.pdu_session_id" showname="pdu session identity: pdu session identity value 1 (1)" size="1" pos="112" show="1" value="01" is in order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x8383fa30" size="4" pos="1" show="0x8383fa30" value="8383fa30" is in order
# <field name="nas_eps.nas_msg_emm_type" showname="nas eps mobility management message type: attach reject (0x44)" size="1" pos="7" show="68" value="44" is out of order
# <field name="nas_eps.bearer_id" showname="0000 .... = eps bearer identity: no eps bearer identity assigned (0)" size="1" pos="12" show="0" value="0" unmaskedvalue="02" is out of order
# <field name="nas_eps.esm.cause" showname="cause: user authentication failed (29)" size="1" pos="15" show="29" value="1d" is out of order
# <field name="nas_eps.security_header_type" showname="1100 .... = security header type: security header for the service request message (12)" size="1" pos="0" show="12" value="c" unmaskedvalue="c7" is out of order
# <field name="" show="short mac - message authentication code (short)" size="2" pos="2" is in order
# <field name="nas_eps.emm.short_mac" showname="message authentication code (short): 0x35d0" size="2" pos="2" show="0x000035d0" value="35d0" is in order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x7366495d" size="4" pos="1" show="0x7366495d" value="7366495d" is in order
# <field name="" show="eps mobile identity - old guti" size="12" pos="9" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="10" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="nas_eps.emm.sgc_cap" showname=".0.. .... = service gap control: not supported" size="1" pos="29" show="0" value="0" unmaskedvalue="90" is out of order
# <field name="" show="tracking area identity - last visited registered tai" size="6" pos="30" is out of order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="59" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0x0f8ac87b" size="4" pos="1" show="0x0f8ac87b" value="0f8ac87b" is in order
# <field name="" show="eps mobile identity - guti" size="13" pos="11" is in order
# <field name="nas_eps.emm.odd_even" showname=".... 0... = odd/even indication: even number of identity digits" size="1" pos="13" show="0" value="0" unmaskedvalue="f6" is out of order
# <field name="" show="tracking area identity list" size="8" pos="24" is in order
# <field name="nas_eps.emm.esr_ps" showname="..0. .... = support of extended service request for packet services: not supported" size="1" pos="38" show="0" value="0" unmaskedvalue="01" is out of order
# <field name="nas_eps.msg_auth_code" showname="message authentication code: 0xcae9bbf1" size="4" pos="1" show="0xcae9bbf1" value="cae9bbf1" is in order
# <field name="nas_eps.security_header_type" showname="1100 .... = security header type: security header for the service request message (12)" size="1" pos="0" show="12" value="c" unmaskedvalue="c7" is out of order
# <field name="" show="short mac - message authentication code (short)" size="2" pos="2" is in order
# <field name="nas_eps.emm.short_mac" showname="message authentication code (short): 0x72b5" size="2" pos="2" show="0x000072b5" value="72b5" is in order
# <field name="nas_eps.security_header_type" showname="1100 .... = security header type: security header for the service request message (12)" size="1" pos="0" show="12" value="c" unmaskedvalue="c7" is out of order
# <field name="" show="short mac - message authentication code (short)" size="2" pos="2" is in order
# <field name="nas_eps.emm.short_mac" showname="message authentication code (short): 0xbeb4" size="2" pos="2" show="0x0000beb4" value="beb4" is in order
# <field name="gsm_a.cmsp" showname=".... .1.. = cmsp: cm service prompt: network initiated mo cm connection request supported for at least one cm protocol" size="1" pos="649" show="1" value="1" unmaskedvalue="a6" is out of order
# <field name="nas_eps.security_header_type" showname="1100 .... = security header type: security header for the service request message (12)" size="1" pos="0" show="12" value="c" unmaskedvalue="c7" is out of order
# <field name="" show="short mac - message authentication code (short)" size="2" pos="2" is in order
# <field name="nas_eps.emm.short_mac" showname="message authentication code (short): 0x19a9" size="2" pos="2" show="0x000019a9" value="19a9" is in order
# <field name="nas_eps.security_header_type" showname="1100 .... = security header type: security header for the service request message (12)" size="1" pos="0" show="12" value="c" unmaskedvalue="c7" is out of order
# <field name="" show="short mac - message authentication code (short)" size="2" pos="2" is in order
# <field name="nas_eps.emm.short_mac" showname="message authentication code (short): 0x552e" size="2" pos="2" show="0x0000552e" value="552e" is in order
# tensor([0, 1, 0,  ..., 1, 0, 0])
